# %% [markdown]
# <a href="https://colab.research.google.com/github/Vickycp/Machine-Learning/blob/master/assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf

# %%
  x1=tf.Variable([1,2],dtype=tf.int32)
  x1
# Out:
# <tf.Variable 'Variable:0' shape=(2,) dtype=int32, numpy=array([1, 2], dtype=int32)>

# %%
x2=tf.Variable([[1,2],[2,3],[4,5]],dtype=tf.int32)
print(x2)
tf.shape(x2)
# Out:
# <tf.Variable 'Variable:0' shape=(3, 2) dtype=int32, numpy=
# array([[1, 2],
#        [2, 3],
#        [4, 5]], dtype=int32)>
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([3, 2], dtype=int32)>

# %%
print(tf.rank(x2))
# Out:
# tf.Tensor(2, shape=(), dtype=int32)

# %%
tf.reshape(x2,[2,3])
# Out:
# <tf.Tensor: shape=(2, 3), dtype=int32, numpy=
# array([[1, 2, 2],
#        [3, 4, 5]], dtype=int32)>

# %%
tf.transpose(a=x2)
# Out:
# <tf.Tensor: shape=(2, 3), dtype=int32, numpy=
# array([[1, 2, 4],
#        [2, 3, 5]], dtype=int32)>

# %%
from keras.datasets import imdb
(x_train, y_train),(x_test, y_test)= imdb.load_data(num_words=10000)
# Out:
# ...
# 17473536/17464789 [==============================] - 0s 0us/step
# <string>:6: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/keras/datasets/imdb.py:155: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   x_train, y_train = np.array(xs[:idx]), np.array(labels[:idx])
# ...

# %%
for i in range(0,10):
  print(x_train[i])
# Out:
# [1, 14, 22, 16, 43, 530, 973, 1622, 1385, 65, 458, 4468, 66, 3941, 4, 173, 36, 256, 5, 25, 100, 43, 838, 112, 50, 670, 2, 9, 35, 480, 284, 5, 150, 4, 172, 112, 167, 2, 336, 385, 39, 4, 172, 4536, 1111, 17, 546, 38, 13, 447, 4, 192, 50, 16, 6, 147, 2025, 19, 14, 22, 4, 1920, 4613, 469, 4, 22, 71, 87, 12, 16, 43, 530, 38, 76, 15, 13, 1247, 4, 22, 17, 515, 17, 12, 16, 626, 18, 2, 5, 62, 386, 12, 8, 316, 8, 106, 5, 4, 2223, 5244, 16, 480, 66, 3785, 33, 4, 130, 12, 16, 38, 619, 5, 25, 124, 51, 36, 135, 48, 25, 1415, 33, 6, 22, 12, 215, 28, 77, 52, 5, 14, 407, 16, 82, 2, 8, 4, 107, 117, 5952, 15, 256, 4, 2, 7, 3766, 5, 723, 36, 71, 43, 530, 476, 26, 400, 317, 46, 7, 4, 2, 1029, 13, 104, 88, 4, 381, 15, 297, 98, 32, 2071, 56, 26, 141, 6, 194, 7486, 18, 4, 226, 22, 21, 134, 476, 26, 480, 5, 144, 30, 5535, 18, 51, 36, 28, 224, 92, 25, 104, 4, 226, 65, 16, 38, 1334, 88, 12, 16, 283, 5, 16, 4472, 113, 103, 32, 15, 16, 5345, 19, 178, 32]
# ...

# %%
for i in range(0,10):
  print(x_test[i])
# Out:
# [1, 591, 202, 14, 31, 6, 717, 10, 10, 2, 2, 5, 4, 360, 7, 4, 177, 5760, 394, 354, 4, 123, 9, 1035, 1035, 1035, 10, 10, 13, 92, 124, 89, 488, 7944, 100, 28, 1668, 14, 31, 23, 27, 7479, 29, 220, 468, 8, 124, 14, 286, 170, 8, 157, 46, 5, 27, 239, 16, 179, 2, 38, 32, 25, 7944, 451, 202, 14, 6, 717]
# ...

# %%
class_names=["negative","positive"]

# %%
word_index=imdb.get_word_index()
word_index["hello"]
# Out:
# ...
# 1654784/1641221 [==============================] - 0s 0us/step
# 4822

# %%
from keras.preprocessing.sequence import pad_sequences

# %%
x_train=pad_sequences(x_train,value= word_index['the'],padding="post",maxlen=256)

x_test=pad_sequences(x_test,value= word_index['the'],padding="post",maxlen=256)

# %%
from keras.models import Sequential
from tensorflow.keras.layers import Dense , Embedding,GlobalAveragePooling1D

# %%
model=Sequential([Embedding(10000,16),GlobalAveragePooling1D(),
                  Dense(16,activation="relu"),
                  Dense(1,activation="sigmoid")])

# %%
model.compile(loss="binary_crossentropy",
              optimizer="adam",
              metrics=["accuracy"])

# %%
loss, acc=model.evaluate(x_test,y_test)
# Out:
# 782/782 [==============================] - 18s 1ms/step - loss: 0.6931 - accuracy: 0.4933
